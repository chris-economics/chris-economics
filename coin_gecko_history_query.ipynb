# %%
import pandas as pd
import time
import json
import os
import requests

def get_top_coins(limit, category=None):
    """Function to grab top `limit` coins from coingecko's main page. You can also provide a category that is defaulted to none. Outputs a list of token ids."""
    url = "https://api.coingecko.com/api/v3/coins/markets"
    params = {
        "vs_currency": "usd",
        "order": "market_cap_desc",
        "per_page": 250,
        "page": 1,
    }
    if category: # If category provided, add it to the list of parameters.
        params['category']=category

    all_coins=[]
    for page in range(1, (limit//250)+2):
        params["page"]=page
        response = requests.get(url,params=params)
        if response.status_code==200:
            all_coins.extend(response.json())
            print(f'Page {page} successful')
        else:
            print(f"Error fetching page {page}: {response.status_code}")
    coin_list = [coin['id'] for coin in all_coins[:limit]] # Get just the top N = limit
    return coin_list

def get_category_list():
    """Function to grab a list of categories available to search using the above function to grab coin ids."""
    category_list=requests.get("https://api.coingecko.com/api/v3/coins/categories/list").json()
    return category_list

def fetch_market_data(coin_ids, path, days=365, currency="usd"):
    """ For all coins in coin list, grab market data last 365 days. 
    Greater than 365 days will provide error 401 permission denied - not available at the free API endpoint.
    currency defaults to usd
    must provide a path for files to be saved. Saves to path with naming convention "coin_gecko"+token_id
    returns a concatenated dataset of all successful coins and a list of failed coins for future runs.
    """
    base_url = "https://api.coingecko.com/api/v3/coins/{}/market_chart"
    data = {}
    failed = []
    fail_counter=0
    for coin in coin_ids:
        url = base_url.format(coin)
        params = {"vs_currency": currency, "days": days, "interval": "daily"}
        response = requests.get(url, params=params)
        if response.status_code == 200:
            print(f"Successfully loaded {coin}")
            market_data = response.json()
            prices = market_data.get("prices", [])
            market_caps = market_data.get("market_caps", [])
            volume = market_data.get("total_volumes")
            df = pd.DataFrame({
                "timestamp": [entry[0] for entry in prices],
                "price": [entry[1] for entry in prices],
                "market_cap": [entry[1] for entry in market_caps],
                "volume": [entry[1] for entry in volume]
            })
            df["timestamp"] = pd.to_datetime(df["timestamp"], unit="ms")
            data[coin] = df
            file_path = fr'{path}\coin_gecko_{coin}.csv'
            df.to_csv(file_path, encoding='utf-8', index=False, header=True)
            fail_counter=0
        else:
            print(f"Failed to fetch data for {coin}: {response.status_code}")
            failed.append(coin)
            time.sleep(61)
            fail_counter+=1
            if fail_counter>10:
                print("Failed to retrieve tokens, operation aborted")
                break
        time.sleep(1)
    return data, failed

def get_failed_list(token_list, path):
    """ 
    Takes list of tokens and checks local storage to see which tokens aren't there
    must provide path where token data is stored
    Returns list of missing tokens and list of currently stored tokens
    """
    files = os.listdir(path)
    succeeded_list = [i.replace('coin_gecko_','') for i in files]
    succeeded_list = [i.replace('.csv','') for i in succeeded_list]
    failed_list = [i for i in token_list if i not in succeeded_list]
    return failed_list, succeeded_list

def compile_files(name, path):
    """ 
    takes in a name for your final dataframe and a path where the coin data is stored.
    returns dataframe of all tokens compiled. Filter this dataset after the fact, the operation is very fast so filtering is more straightforward post.
    """

    files = os.listdir(path)
    df = pd.DataFrame(columns={'timestamp':[],'price':[],'market_cap':[],'volume':[],'token':[]})
    for i, j in enumerate(files):
        new_path = fr'{path}\{j}'
        dd=pd.read_csv(new_path)
        tname=j.replace('coin_gecko_','')
        tname=tname.replace('.csv','')
        dd['token'] = tname
        df = pd.concat([df,dd])
    new_path = fr'{path}\{name}.csv'
    df.to_csv(new_path, encoding='utf-8', index=False, header=True)
    return df

def repeat_get_token_data(limit,path,cat):
    """ 
    Runs fetch_market_data on a loop until the fail list is empty or until fail list equals same length as last iteration then quits loop. 
    Saves files to path, doesn't return proper dataframe. 
    """
    # Get list of tokens 
    coin_list=get_top_coins(limit, cat)
    coin_list=get_failed_list(coin_list, path)[0]

    # Begin searching. Repeat until there are no tokens left that I don't already have.
    print(f'Will begin retreiving {len(coin_list)} coins after 60 seconds')
    time.sleep(60)

    self_destruct=True
    while len(coin_list)>0:
        sd=len(coin_list)
        coin_list = fetch_market_data(coin_list, path)[1] # Call the function, which activates the data retrieval process. Once it's done you'll have a list of failed (index 1) then keep running the operation until that list is empty.
        self_destruct=(sd-len(coin_list))>=1 # If the list is the same length as it was when it started, exit the loop, you're no longer making progress.
        print(f'{len(coin_list)} tokens failed')
        if self_destruct:
            print("Repeating Operation")
        else:
            print(f"Unable to grab last {len(coin_list)} tokens")
            break
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Arguments
limit = 500
path = fr'C:\Users\Name\files_etc'
cat = 'gaming'
repeat_get_token_data(limit,path,cat)
# Out:
# Page 1 successful
# Page 2 successful
# Page 3 successful
# Will begin retreiving 426 coins after 60 seconds
# Successfully loaded my-neighbor-alice
# Successfully loaded seedify-fund
# Successfully loaded magic
# Successfully loaded altura
# Successfully loaded xterio
# Failed to fetch data for dar-open-network: 429
# Successfully loaded marblex
# Successfully loaded endurance
# Successfully loaded mobox
# Successfully loaded hooked-protocol
# Successfully loaded radio-caca
# Failed to fetch data for gods-unchained: 429
# Successfully loaded vulcan-forged
# Successfully loaded pixels
# Successfully loaded alien-worlds
# Successfully loaded xpla
# Successfully loaded games-for-a-living
# Failed to fetch data for myria: 429
# Successfully loaded catizen
# Failed to fetch data for ancient8: 429
# Successfully loaded neuralai
# Successfully loaded metacade
# Successfully loaded seraph
# Successfully loaded nakamoto-games
# Successfully loaded karrat
# Failed to fetch data for aavegotchi: 429
# Successfully loaded ultra
# Successfully loaded open-loot
# Failed to fetch data for my-lovely-coin: 429
# Successfully loaded neuron
# Successfully loaded miracle-play
# Successfully loaded gamercoin
# Successfully loaded ix-token
# Failed to fetch data for yuli: 429
# Successfully loaded voxies
# Successfully loaded cornucopias
# Successfully loaded the-root-network
# Successfully loaded hytopia
# Failed to fetch data for sappy-seals-pixl: 429
# Successfully loaded rabbitcoin-2
# Successfully loaded volt-inu-2
# Successfully loaded cocos-bcx
# Successfully loaded gamefi
# Failed to fetch data for world-of-dypians: 429
# Successfully loaded pirate-token
# Successfully loaded league-of-kingdoms
# Successfully loaded matr1x
# Successfully loaded karate-combat
# Successfully loaded guild-of-guardians
# Failed to fetch data for sovrun: 429
# Successfully loaded sidus
# Successfully loaded cryptofarmers
# Successfully loaded playdapp
# Successfully loaded otherworld
# Successfully loaded altered-state-token
# Failed to fetch data for mixmarvel: 429
# Successfully loaded galeon
# Successfully loaded cere-network
# Successfully loaded dream-machine-token
# Successfully loaded mon-protocol
# Successfully loaded metahero
# Successfully loaded memefi-2
# Failed to fetch data for avc: 429
# Successfully loaded super-champs
# Successfully loaded blocklords
# Failed to fetch data for wagmi-game-2: 429
# Successfully loaded phantasma
# Successfully loaded wemix-dollar
# Successfully loaded derace
# Successfully loaded artyfact
# Failed to fetch data for katana-inu: 429
# Successfully loaded sipher
# Successfully loaded gameswift
# Successfully loaded ufo-gaming
# Failed to fetch data for moon-tropica: 429
# Successfully loaded heroes-of-mavia
# Successfully loaded punk-2
# Successfully loaded game7
# Successfully loaded sixpack-token-sixp
# Failed to fetch data for defi-kingdoms: 429
# Successfully loaded your-open-metaverse
# Successfully loaded seedworld
# Successfully loaded gamee
# Successfully loaded playa3ull-games-2
# Failed to fetch data for saito: 429
# Successfully loaded shrapnel-2
# Successfully loaded nft-worlds
# Successfully loaded lords
# Successfully loaded passage
# Failed to fetch data for clayton: 429
# Successfully loaded ethos
# Successfully loaded draggin-karma-points
# Successfully loaded catecoin
# Successfully loaded paragonsdao
# Successfully loaded dolz-io
# Failed to fetch data for starlink: 429
# Successfully loaded frenpet
# Successfully loaded tevaera
# Successfully loaded matr1x-fire
# Successfully loaded creo-engine
# Successfully loaded step-app-fitfi
# Failed to fetch data for minativerse: 429
# Successfully loaded island-token
# Successfully loaded the-virtua-kolect
# Successfully loaded gamegpt
# Successfully loaded chain-games
# Successfully loaded qopro
# Successfully loaded kompete
# Failed to fetch data for xana: 429
# Successfully loaded play-2
# Failed to fetch data for everdome: 429
# Successfully loaded yeet
# Successfully loaded pikamoon
# Successfully loaded tonstation
# Successfully loaded ispolink
# Successfully loaded arca
# Failed to fetch data for magiccraft: 429
# Successfully loaded netvrk
# Successfully loaded upland
# Failed to fetch data for metacene: 429
# Successfully loaded holdcoin
# Successfully loaded apeironnft
# Successfully loaded farcana
# Successfully loaded blockgames
# Failed to fetch data for gam3s-gg: 429
# Successfully loaded warped-games
# Successfully loaded godcoin-2
# Successfully loaded splinterlands
# Successfully loaded gensokishis-metaverse
# Failed to fetch data for gamium: 429
# Successfully loaded decentral-games
# Successfully loaded perion
# Successfully loaded settled-ethxy-token
# Successfully loaded zoo
# Failed to fetch data for aiveronica: 429
# Successfully loaded boxbet
# Successfully loaded domi
# Successfully loaded furi
# Successfully loaded exosama-network
# Successfully loaded block-ape-scissors
# Failed to fetch data for brn-metaverse: 429
# Successfully loaded forgotten-playland
# Successfully loaded the-big-five
# Successfully loaded pog-digital
# Successfully loaded neoxa
# Successfully loaded cross-the-ages
# Failed to fetch data for gavun-wud: 429
# Successfully loaded smoovie-phone
# Successfully loaded hodl-2
# Successfully loaded ridotto
# Successfully loaded gamer-arena
# Successfully loaded gamer-tag
# Successfully loaded ppkas
# Failed to fetch data for senate: 429
# Successfully loaded dogami
# Successfully loaded dark-frontiers
# Failed to fetch data for goats-2: 429
# Successfully loaded reality-metaverse
# Successfully loaded skynity-skydust
# Successfully loaded carbify
# Successfully loaded chimaera
# Failed to fetch data for yapster: 429
# Successfully loaded plyr-l1
# Successfully loaded ripples
# Successfully loaded vidya
# Failed to fetch data for rome: 429
# Successfully loaded doglibre
# Successfully loaded reboot
# Successfully loaded bloodloop
# Successfully loaded hdoki
# Failed to fetch data for defi-land: 429
# Successfully loaded defit
# Successfully loaded drunk-robots
# Successfully loaded veloce-vext
# Successfully loaded bag
# Failed to fetch data for revv: 429
# Successfully loaded sekuya-2
# Successfully loaded redfox-labs-2
# Successfully loaded moonprime-games
# Successfully loaded modern-innovation-network-token
# Failed to fetch data for derby-stars-run: 429
# Successfully loaded karat-galaxy
# Successfully loaded raini-studios-token
# Successfully loaded dypius
# Successfully loaded gamestarter
# Successfully loaded spacecatch
# Failed to fetch data for champignons-of-arborethia: 429
# Successfully loaded mch-coin
# Successfully loaded dotmoovs
# Successfully loaded outer-ring
# Successfully loaded vee
# Successfully loaded fate-adventure
# Failed to fetch data for sin-city: 429
# Successfully loaded blockchain-brawlers
# Successfully loaded imaginary-ones
# Successfully loaded yaku
# Successfully loaded gold-fever-native-gold
# Successfully loaded aether-games
# Successfully loaded bullieverse
# Failed to fetch data for polka-city: 429
# Successfully loaded merit-circle
# Failed to fetch data for moonray: 429
# Successfully loaded spacefalcon
# Successfully loaded xyro
# Successfully loaded kapital-dao
# Successfully loaded starheroes
# Successfully loaded rebel-bots
# Failed to fetch data for catboy-3: 429
# Successfully loaded tower
# Successfully loaded gameswap-org
# Failed to fetch data for green-satoshi-token-on-eth: 429
# Successfully loaded watcoin
# Successfully loaded spacem-token
# Successfully loaded galvan
# Successfully loaded game-meteor-coin
# Failed to fetch data for pentagon-games: 429
# Successfully loaded walken
# Successfully loaded avaocado-dao
# Successfully loaded pepper-meme
# Successfully loaded beramoniumcoin
# Failed to fetch data for eldarune: 429
# Successfully loaded booh-world-sol
# Successfully loaded e4c
# Successfully loaded affyn
# Successfully loaded avarik-saga
# Failed to fetch data for gaia-everworld: 429
# Successfully loaded based-bario
# Successfully loaded dose-token
# Successfully loaded crowns
# Successfully loaded mixmob
# Successfully loaded web3war
# Failed to fetch data for pegaxy-stone: 429
# Successfully loaded kibble
# Successfully loaded wam
# Successfully loaded polker
# Successfully loaded morra
# Successfully loaded nftb
# Failed to fetch data for metazero: 429
# Successfully loaded nifty-league
# Successfully loaded mbd-financials
# Successfully loaded revomon-2
# Successfully loaded velhalla
# Successfully loaded waves-ducks
# Successfully loaded gunstar-metaverse
# Failed to fetch data for zookeeper: 429
# Successfully loaded the-unfettered-souls
# Successfully loaded world-earn-play-community
# Failed to fetch data for green-satoshi-token-bsc: 429
# Successfully loaded panoverse
# Successfully loaded mars4
# Successfully loaded forkast
# Successfully loaded metaverser
# Failed to fetch data for heroes-of-nft: 429
# Successfully loaded cryptozoon
# Successfully loaded fear
# Successfully loaded ebisusbay-fortune
# Failed to fetch data for the-three-kingdoms: 429
# Successfully loaded oxya-origin
# Successfully loaded decentrawood
# Successfully loaded cellula
# Successfully loaded tubbi
# Failed to fetch data for wanaka-farm: 429
# Successfully loaded starship
# Successfully loaded nft-champions
# Successfully loaded super-useless-token
# Successfully loaded kdr
# Failed to fetch data for times: 429
# Successfully loaded spartadex
# Successfully loaded metados
# Successfully loaded cryowar-token
# Successfully loaded volaris-games
# Failed to fetch data for fofar: 429
# Successfully loaded fire-stokefire
# Successfully loaded pokpok-golden-egg
# Successfully loaded booh-world
# Successfully loaded sugarverse
# Successfully loaded w3gg
# Failed to fetch data for wombat: 429
# Successfully loaded arcade-2
# Successfully loaded bomber-coin
# Successfully loaded blockchainspace
# Successfully loaded clashub
# Successfully loaded gg-token
# Failed to fetch data for spintop: 429
# Successfully loaded binamon
# Successfully loaded dega-2
# Successfully loaded meme-alliance
# Successfully loaded hero-blaze-three-kingdoms
# Successfully loaded wild-forest-token
# Successfully loaded ozone-metaverse
# Failed to fetch data for alaska-gold-rush: 429
# Successfully loaded midnight-2
# Successfully loaded deepspace
# Failed to fetch data for x-world-games: 429
# Successfully loaded chain-guardians
# Successfully loaded atari
# Successfully loaded satoxcoin
# Successfully loaded dice
# Failed to fetch data for shroom-finance: 429
# Successfully loaded metastrike
# Successfully loaded kleekai
# Successfully loaded axoria
# Failed to fetch data for my-defi-pet: 429
# Successfully loaded engines-of-fury
# Successfully loaded wall-street-games-2
# Successfully loaded forest-knight
# Successfully loaded cocktailbar
# Failed to fetch data for playermon: 429
# Successfully loaded kryptomon
# Successfully loaded frencoin-3
# Successfully loaded wander
# Successfully loaded merge-token
# Failed to fetch data for dope-wars-paper: 429
# Successfully loaded doctorx
# Successfully loaded metafight-token
# Successfully loaded brot
# Successfully loaded unio-coin
# Failed to fetch data for arrland-rum: 429
# Successfully loaded kitty-inu
# Successfully loaded plant-vs-undead-token
# Successfully loaded epiko
# Successfully loaded realm
# Successfully loaded duelnow
# Failed to fetch data for versus-x: 429
# Successfully loaded win-2
# Successfully loaded vempire-ddao
# Successfully loaded scotty-beam
# Successfully loaded landrocker
# Successfully loaded rainicorn
# Failed to fetch data for ponchiqs: 429
# Successfully loaded chainccolosseumphoenix
# Successfully loaded mxs-games
# Successfully loaded hyperchainx
# Successfully loaded blockchain-monster-hunt
# Successfully loaded battle-pets
# Successfully loaded materium
# Failed to fetch data for goldbrick: 429
# Successfully loaded blackpool-token
# Failed to fetch data for shockwaves: 429
# Successfully loaded rainbow-token-2
# Successfully loaded clubmoon
# Successfully loaded metafighter
# Successfully loaded fabwelt
# Successfully loaded legends-of-elysium
# Failed to fetch data for pancake-hunny: 429
# Successfully loaded lucha
# Successfully loaded bezoge-earth
# Failed to fetch data for rouge-studio: 429
# Successfully loaded fortune-favours-the-brave
# Successfully loaded metatrace
# Successfully loaded mox-studio
# Successfully loaded heroeschained
# Failed to fetch data for fabled-adventure-fap: 429
# Successfully loaded ton-tycoon
# Successfully loaded blade-2
# Successfully loaded battle-tech-by-virtuals
# Successfully loaded milk
# Failed to fetch data for metalcore: 429
# Successfully loaded param
# Successfully loaded pumlx
# Successfully loaded chronicle
# Successfully loaded guild-of-heroes
# Failed to fetch data for goons-of-balatroon: 429
# Successfully loaded token-in
# Successfully loaded realfevr
# Successfully loaded rainmaker-games
# Successfully loaded must
# Successfully loaded good-games-guild
# Failed to fetch data for kogin-by-virtuals: 429
# Successfully loaded ogc
# Successfully loaded calvaria-doe
# Successfully loaded fit
# Successfully loaded humandao
# Successfully loaded mist
# Failed to fetch data for faraland: 429
# Successfully loaded castle-of-blackwater
# Successfully loaded galaxy-fight-club
# Successfully loaded retrocraft
# Successfully loaded crypto-raiders
# Successfully loaded catbox
# Successfully loaded gnme-mining-game
# Failed to fetch data for decentral-games-ice: 429
# Successfully loaded cryptoblades
# Successfully loaded scorum
# Failed to fetch data for utgard: 429
# Successfully loaded 2077-code
# Successfully loaded hive-game-token
# Successfully loaded crypto-royale
# Successfully loaded unix
# Failed to fetch data for dragon-crypto-aurum: 429
# Successfully loaded monsta-infinite
# Successfully loaded spellfire
# Successfully loaded nftmall
# Failed to fetch data for exeedme: 429
# Successfully loaded defina-finance
# Successfully loaded rough-love-potion
# Successfully loaded gamespad
# Successfully loaded solordi
# Failed to fetch data for pineye: 429
# Successfully loaded momoai
# Successfully loaded game-fantasy-token
# Successfully loaded crypto-unicorns
# Successfully loaded robokiden
# Failed to fetch data for revenant: 429
# Successfully loaded seed-2
# Successfully loaded super-meme-fighter
# Successfully loaded crabada
# Successfully loaded playnity
# Failed to fetch data for koi-4: 429
# Successfully loaded kawaii-islands
# Successfully loaded crusaders-of-crypto
# Successfully loaded iq-protocol
# Successfully loaded game-money
# Successfully loaded kcal
# Failed to fetch data for defi-warrior: 429
# Successfully loaded guildfi
# Successfully loaded ethermon
# Successfully loaded king-of-legends-2
# Successfully loaded nitro-league
# Successfully loaded genesis-worlds
# Failed to fetch data for zodium: 429
# Successfully loaded decentral-games-old
# Successfully loaded wrapped-virgin-gen-0-cryptokitties
# Successfully loaded ducky-city
# Successfully loaded sypher
# Successfully loaded wizardia
# 83 tokens failed
# Repeating Operation
# Successfully loaded dar-open-network
# Failed to fetch data for gods-unchained: 429
# Successfully loaded myria
# Failed to fetch data for ancient8: 429
# Successfully loaded aavegotchi
# Successfully loaded my-lovely-coin
# Successfully loaded yuli
# Successfully loaded sappy-seals-pixl
# Successfully loaded world-of-dypians
# Failed to fetch data for sovrun: 429
# Successfully loaded mixmarvel
# Successfully loaded avc
# Failed to fetch data for wagmi-game-2: 429
# Successfully loaded katana-inu
# Successfully loaded moon-tropica
# Successfully loaded defi-kingdoms
# Successfully loaded saito
# Failed to fetch data for clayton: 429
# Successfully loaded starlink
# Successfully loaded minativerse
# Successfully loaded xana
# Successfully loaded everdome
# Failed to fetch data for magiccraft: 429
# Successfully loaded metacene
# Successfully loaded gam3s-gg
# Successfully loaded gamium
# Successfully loaded aiveronica
# Failed to fetch data for brn-metaverse: 429
# Successfully loaded gavun-wud
# Successfully loaded senate
# Successfully loaded goats-2
# Successfully loaded yapster
# Successfully loaded rome
# Failed to fetch data for defi-land: 429
# Successfully loaded revv
# Successfully loaded derby-stars-run
# Successfully loaded champignons-of-arborethia
# Successfully loaded sin-city
# Successfully loaded polka-city
# Failed to fetch data for moonray: 429
# Successfully loaded catboy-3
# Successfully loaded green-satoshi-token-on-eth
# Successfully loaded pentagon-games
# Successfully loaded eldarune
# Successfully loaded gaia-everworld
# Successfully loaded pegaxy-stone
# Failed to fetch data for metazero: 429
# Successfully loaded zookeeper
# Successfully loaded green-satoshi-token-bsc
# Failed to fetch data for heroes-of-nft: 429
# Successfully loaded the-three-kingdoms
# Successfully loaded wanaka-farm
# Successfully loaded times
# Successfully loaded fofar
# Failed to fetch data for wombat: 429
# Successfully loaded spintop
# Successfully loaded alaska-gold-rush
# Successfully loaded x-world-games
# Failed to fetch data for shroom-finance: 429
# Successfully loaded my-defi-pet
# Successfully loaded playermon
# Successfully loaded dope-wars-paper
# Successfully loaded arrland-rum
# Failed to fetch data for versus-x: 429
# Successfully loaded ponchiqs
# Successfully loaded goldbrick
# Successfully loaded shockwaves
# Successfully loaded pancake-hunny
# Failed to fetch data for rouge-studio: 429
# Successfully loaded fabled-adventure-fap
# Successfully loaded metalcore
# Successfully loaded goons-of-balatroon
# Successfully loaded kogin-by-virtuals
# Failed to fetch data for faraland: 429
# Successfully loaded decentral-games-ice
# Successfully loaded utgard
# Successfully loaded dragon-crypto-aurum
# Successfully loaded exeedme
# Successfully loaded pineye
# Failed to fetch data for revenant: 429
# Successfully loaded koi-4
# Successfully loaded defi-warrior
# Successfully loaded zodium
# 17 tokens failed
# Repeating Operation
# Successfully loaded gods-unchained
# Successfully loaded ancient8
# Failed to fetch data for sovrun: 429
# Successfully loaded wagmi-game-2
# Successfully loaded clayton
# Successfully loaded magiccraft
# Successfully loaded brn-metaverse
# Successfully loaded defi-land
# Successfully loaded moonray
# Failed to fetch data for metazero: 429
# Successfully loaded heroes-of-nft
# Successfully loaded wombat
# Failed to fetch data for shroom-finance: 429
# Successfully loaded versus-x
# Successfully loaded rouge-studio
# Successfully loaded faraland
# Successfully loaded revenant
# 3 tokens failed
# Repeating Operation
# Failed to fetch data for sovrun: 429
# Successfully loaded metazero
# Successfully loaded shroom-finance
# 1 tokens failed
# Repeating Operation
# Successfully loaded sovrun
# 0 tokens failed
# Repeating Operation

# %%
# Run the algo
coin_list = get_top_coins()
market_data = fetch_market_data(coin_list)
print("failed:",market_data[1])

# %%
try_again()
# Out:
# Error fetching page 1: 429
# All tokens have been collected!
# []

# %%
compile_files()
# Out:
# C:\Users\Chris\AppData\Local\Temp\ipykernel_36276\2483705050.py:11: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,dd])
#                timestamp     price    market_cap        volume   token
# 0    2024-03-07 00:00:00  0.527185  4.462967e+08  1.087883e+08      0x
# 1    2024-03-08 00:00:00  0.515601  4.384284e+08  9.179183e+07      0x
# 2    2024-03-09 00:00:00  0.562559  4.764888e+08  6.464024e+07      0x
# 3    2024-03-10 00:00:00  0.576627  4.882599e+08  4.198141e+07      0x
# 4    2024-03-11 00:00:00  0.800715  6.831453e+08  2.931050e+08      0x
# ..                   ...       ...           ...           ...     ...
# 259  2025-03-03 00:00:00  0.103972  3.823543e+08  5.494609e+07  zksync
# 260  2025-03-04 00:00:00  0.088192  3.240637e+08  5.014336e+07  zksync
# 261  2025-03-05 00:00:00  0.083050  3.053176e+08  6.365744e+07  zksync
# 262  2025-03-06 00:00:00  0.086683  3.190064e+08  3.701773e+07  zksync
# 263  2025-03-06 17:53:16  0.083879  3.082534e+08  3.160273e+07  zksync
#
# [178846 rows x 5 columns]
